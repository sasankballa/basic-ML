# %% [markdown]
# <a href="https://colab.research.google.com/github/sasankballa/basic-ML/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
log = pd.read_csv('/tested.csv')
log
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
log.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False   True     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False   True     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 413        False     False   False  False  ...   False  False   True     False
# 414        False     False   False  False  ...   False  False  False     False
# 415        False     False   False  False  ...   False  False   True     False
# 416        False     False   False  False  ...   False  False   True     False
# 417        False     False   False  False  ...   False  False   True     False
#
# [418 rows x 12 columns]

# %% [markdown]
# **LINE PLOT**

# %%
sns.lineplot(data=log,x="Age",y="Survived")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **HEAT MAP (NULL VALUES)**

# %%
sns.heatmap(log.isnull())

# %% [markdown]
# ## ***count plot***

# %%
sns.set_style('darkgrid')
sns.countplot(x='Survived',hue='Sex',data=log,palette='BuGn')

# %%
sns.set_style('darkgrid')
sns.countplot(x='Survived',hue='Pclass',data=log,palette='BuGn')

# %%
sns.set_style('darkgrid')
sns.countplot(x='SibSp',data=log,palette='BuGn')

# %% [markdown]
# DIST **PLOT**

# %%
sns.distplot(log['Age'].dropna(),color='red',bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **BAR PLOT**

# %%
sns.barplot(data=log,x='Age',y="Survived")

# %% [markdown]
# **Box plots**

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='Pclass',y='Age',data=log,palette='Dark2_r')

# %% [markdown]
# **SCATTER PLOTS**

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='Pclass',y='Age',data=log,palette='Dark2_r')

# %%
sns.pairplot(log)

# %% [markdown]
# **HEAT MAP WITHOUT NAN VALUES**

# %%
def null_age(cols):
  Age = cols[0]
  Pclass = cols[1]
   
  if pd.isnull(Age):
    if Pclass ==1:
      return 47
    elif Pclass == 2:
      return 39
    else:
      return 44
  else:
    return Age

# %%
log['Age'] = log[['Age','Pclass']].apply(null_age,axis=1)

# %%
sns.heatmap(log.isnull())

# %% [markdown]
# **CLEANING DATASET**

# %%
log.drop('Cabin',axis=1,inplace=True)

# %%
log.head(88)
# Out:
#     PassengerId  Survived  Pclass  ...     Ticket     Fare  Embarked
# 0           892         0       3  ...     330911   7.8292         Q
# 1           893         1       3  ...     363272   7.0000         S
# 2           894         0       2  ...     240276   9.6875         Q
# 3           895         0       3  ...     315154   8.6625         S
# 4           896         1       3  ...    3101298  12.2875         S
# ..          ...       ...     ...  ...        ...      ...       ...
# 83          975         0       3  ...     349238   7.8958         S
# 84          976         0       2  ...     240261  10.7083         Q
# 85          977         0       3  ...       2660  14.4542         C
# 86          978         1       3  ...     330844   7.8792         Q
# 87          979         1       3  ...  A/4 31416   8.0500         S
#
# [88 rows x 11 columns]
